# %% [markdown]
# # Cifar-10 이미지 분류

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os
import numpy as np

# %%
# 나중에 지정될 변수의 값을 미리 세팅
BATCH_SIZE = 32
NUM_CLASSES = 10
EPOCHS = 100
DATA_AUGMENTATION = True
NUM_PREDICTIONS = 20
SAVE_DIR = os.path.join(os.getcwd(), 'model')
MODEL_NAME = 'keras_cifar10_trained_model.h5'

# %%
# The data, split between train and test sets:
(x_train, y_train0), (x_test, y_test0) = cifar10.load_data()
print('x_train shape', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ### 데이터 확인

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(141)
plt.imshow(x_train[0], interpolation="bicubic")
plt.grid(False)
plt.subplot(142)
plt.imshow(x_train[4], interpolation="bicubic")
plt.grid(False)
plt.subplot(143)
plt.imshow(x_train[8], interpolation="bicubic")
plt.grid(False)
plt.subplot(144)
plt.imshow(x_train[12], interpolation="bicubic")
plt.grid(False)
plt.show()

# %%
y_train0[0]
# Out:
# array([6], dtype=uint8)

# %%
# 자료형을 실수로 변환한 후 정규화
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# One-hot enchoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train0, NUM_CLASSES)
y_test = to_categorical(y_test0, NUM_CLASSES)
y_train.shape, y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ### 모델 정의 / 설정 / 학습

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), #필터=마스크=커널 갯수32
                 padding='same',
                 input_shape=x_train.shape[1:], #(50000, 32, 32, 3)에서 shape[1:]은 뒤에 3개만 ㅋ.ㅋ
                 activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
opt = RMSprop(learning_rate = 0.0001, decay=1e-6)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
modelpath = "model/cifar10-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss',
                               verbose=1,save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(x_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_split=0.2,
                    shuffle=True,
                    callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 9s 5ms/step - loss: 2.0234 - accuracy: 0.2491 - val_loss: 1.5834 - val_accuracy: 0.4257
#
# Epoch 00001: val_loss improved from inf to 1.58341, saving model to model/cifar10-cnn-01-1.5834.hdf5
# Epoch 2/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5895 - accuracy: 0.4244 - val_loss: 1.4089 - val_accuracy: 0.5004
#
# Epoch 00002: val_loss improved from 1.58341 to 1.40891, saving model to model/cifar10-cnn-02-1.4089.hdf5
# Epoch 3/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4337 - accuracy: 0.4856 - val_loss: 1.3117 - val_accuracy: 0.5362
#
# Epoch 00003: val_loss improved from 1.40891 to 1.31166, saving model to model/cifar10-cnn-03-1.3117.hdf5
# Epoch 4/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3323 - accuracy: 0.5227 - val_loss: 1.2379 - val_accuracy: 0.5637
#
# Epoch 00004: val_loss improved from 1.31166 to 1.23788, saving model to model/cifar10-cnn-04-1.2379.hdf5
# Epoch 5/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2370 - accuracy: 0.5605 - val_loss: 1.1300 - val_accuracy: 0.6055
#
# Epoch 00005: val_loss improved from 1.23788 to 1.13003, saving model to model/cifar10-cnn-05-1.1300.hdf5
# Epoch 6/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1701 - accuracy: 0.5914 - val_loss: 1.0786 - val_accuracy: 0.6223
#
# Epoch 00006: val_loss improved from 1.13003 to 1.07859, saving model to model/cifar10-cnn-06-1.0786.hdf5
# Epoch 7/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1020 - accuracy: 0.6139 - val_loss: 1.0583 - val_accuracy: 0.6327
#
# Epoch 00007: val_loss improved from 1.07859 to 1.05831, saving model to model/cifar10-cnn-07-1.0583.hdf5
# Epoch 8/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0614 - accuracy: 0.6257 - val_loss: 1.0083 - val_accuracy: 0.6488
#
# Epoch 00008: val_loss improved from 1.05831 to 1.00828, saving model to model/cifar10-cnn-08-1.0083.hdf5
# Epoch 9/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0222 - accuracy: 0.6420 - val_loss: 0.9594 - val_accuracy: 0.6666
#
# Epoch 00009: val_loss improved from 1.00828 to 0.95939, saving model to model/cifar10-cnn-09-0.9594.hdf5
# Epoch 10/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9855 - accuracy: 0.6577 - val_loss: 0.9055 - val_accuracy: 0.6856
#
# Epoch 00010: val_loss improved from 0.95939 to 0.90547, saving model to model/cifar10-cnn-10-0.9055.hdf5
# Epoch 11/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9482 - accuracy: 0.6705 - val_loss: 0.8757 - val_accuracy: 0.7003
#
# Epoch 00011: val_loss improved from 0.90547 to 0.87566, saving model to model/cifar10-cnn-11-0.8757.hdf5
# Epoch 12/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9193 - accuracy: 0.6789 - val_loss: 0.8613 - val_accuracy: 0.6979
#
# Epoch 00012: val_loss improved from 0.87566 to 0.86130, saving model to model/cifar10-cnn-12-0.8613.hdf5
# Epoch 13/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8852 - accuracy: 0.6949 - val_loss: 0.8329 - val_accuracy: 0.7100
#
# Epoch 00013: val_loss improved from 0.86130 to 0.83287, saving model to model/cifar10-cnn-13-0.8329.hdf5
# Epoch 14/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8803 - accuracy: 0.6953 - val_loss: 0.8228 - val_accuracy: 0.7163
#
# Epoch 00014: val_loss improved from 0.83287 to 0.82282, saving model to model/cifar10-cnn-14-0.8228.hdf5
# Epoch 15/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8558 - accuracy: 0.7055 - val_loss: 0.8377 - val_accuracy: 0.7108
#
# Epoch 00015: val_loss did not improve from 0.82282
# Epoch 16/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8255 - accuracy: 0.7137 - val_loss: 0.7991 - val_accuracy: 0.7258
#
# Epoch 00016: val_loss improved from 0.82282 to 0.79909, saving model to model/cifar10-cnn-16-0.7991.hdf5
# Epoch 17/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8223 - accuracy: 0.7159 - val_loss: 0.8041 - val_accuracy: 0.7222
#
# Epoch 00017: val_loss did not improve from 0.79909
# Epoch 18/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8140 - accuracy: 0.7184 - val_loss: 0.7816 - val_accuracy: 0.7305
#
# Epoch 00018: val_loss improved from 0.79909 to 0.78157, saving model to model/cifar10-cnn-18-0.7816.hdf5
# Epoch 19/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7945 - accuracy: 0.7245 - val_loss: 0.8004 - val_accuracy: 0.7187
#
# Epoch 00019: val_loss did not improve from 0.78157
# Epoch 20/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7780 - accuracy: 0.7326 - val_loss: 0.7525 - val_accuracy: 0.7385
#
# Epoch 00020: val_loss improved from 0.78157 to 0.75248, saving model to model/cifar10-cnn-20-0.7525.hdf5
# Epoch 21/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7727 - accuracy: 0.7334 - val_loss: 0.7581 - val_accuracy: 0.7391
#
# Epoch 00021: val_loss did not improve from 0.75248
# Epoch 22/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7744 - accuracy: 0.7323 - val_loss: 0.7278 - val_accuracy: 0.7450
#
# Epoch 00022: val_loss improved from 0.75248 to 0.72784, saving model to model/cifar10-cnn-22-0.7278.hdf5
# Epoch 23/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7467 - accuracy: 0.7448 - val_loss: 0.7428 - val_accuracy: 0.7434
#
# Epoch 00023: val_loss did not improve from 0.72784
# Epoch 24/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7463 - accuracy: 0.7451 - val_loss: 0.7505 - val_accuracy: 0.7436
#
# Epoch 00024: val_loss did not improve from 0.72784
# Epoch 25/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7365 - accuracy: 0.7466 - val_loss: 0.7241 - val_accuracy: 0.7514
#
# Epoch 00025: val_loss improved from 0.72784 to 0.72407, saving model to model/cifar10-cnn-25-0.7241.hdf5
# Epoch 26/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7335 - accuracy: 0.7497 - val_loss: 0.7199 - val_accuracy: 0.7549
#
# Epoch 00026: val_loss improved from 0.72407 to 0.71990, saving model to model/cifar10-cnn-26-0.7199.hdf5
# Epoch 27/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7278 - accuracy: 0.7517 - val_loss: 0.7148 - val_accuracy: 0.7565
#
# Epoch 00027: val_loss improved from 0.71990 to 0.71478, saving model to model/cifar10-cnn-27-0.7148.hdf5
# Epoch 28/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7212 - accuracy: 0.7531 - val_loss: 0.7179 - val_accuracy: 0.7664
#
# Epoch 00028: val_loss did not improve from 0.71478
# Epoch 29/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7118 - accuracy: 0.7589 - val_loss: 0.6934 - val_accuracy: 0.7623
#
# Epoch 00029: val_loss improved from 0.71478 to 0.69340, saving model to model/cifar10-cnn-29-0.6934.hdf5
# Epoch 30/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7167 - accuracy: 0.7592 - val_loss: 0.6808 - val_accuracy: 0.7687
#
# Epoch 00030: val_loss improved from 0.69340 to 0.68080, saving model to model/cifar10-cnn-30-0.6808.hdf5
# Epoch 31/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7106 - accuracy: 0.7571 - val_loss: 0.7601 - val_accuracy: 0.7462
#
# Epoch 00031: val_loss did not improve from 0.68080
# Epoch 32/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6957 - accuracy: 0.7651 - val_loss: 0.6824 - val_accuracy: 0.7712
#
# Epoch 00032: val_loss did not improve from 0.68080
# Epoch 33/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6938 - accuracy: 0.7653 - val_loss: 0.6881 - val_accuracy: 0.7632
#
# Epoch 00033: val_loss did not improve from 0.68080
# Epoch 34/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6831 - accuracy: 0.7667 - val_loss: 0.6986 - val_accuracy: 0.7617
#
# Epoch 00034: val_loss did not improve from 0.68080
# Epoch 35/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6851 - accuracy: 0.7673 - val_loss: 0.6664 - val_accuracy: 0.7726
#
# Epoch 00035: val_loss improved from 0.68080 to 0.66639, saving model to model/cifar10-cnn-35-0.6664.hdf5
# Epoch 36/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6765 - accuracy: 0.7713 - val_loss: 0.6631 - val_accuracy: 0.7778
#
# Epoch 00036: val_loss improved from 0.66639 to 0.66314, saving model to model/cifar10-cnn-36-0.6631.hdf5
# Epoch 37/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6781 - accuracy: 0.7699 - val_loss: 0.6804 - val_accuracy: 0.7703
#
# Epoch 00037: val_loss did not improve from 0.66314
# Epoch 38/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6643 - accuracy: 0.7777 - val_loss: 0.6672 - val_accuracy: 0.7785
#
# Epoch 00038: val_loss did not improve from 0.66314
# Epoch 39/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6667 - accuracy: 0.7782 - val_loss: 0.6992 - val_accuracy: 0.7653
#
# Epoch 00039: val_loss did not improve from 0.66314
# Epoch 40/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6664 - accuracy: 0.7736 - val_loss: 0.6505 - val_accuracy: 0.7800
#
# Epoch 00040: val_loss improved from 0.66314 to 0.65054, saving model to model/cifar10-cnn-40-0.6505.hdf5
# Epoch 41/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6562 - accuracy: 0.7777 - val_loss: 0.6797 - val_accuracy: 0.7740
#
# Epoch 00041: val_loss did not improve from 0.65054
# Epoch 42/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6620 - accuracy: 0.7774 - val_loss: 0.6640 - val_accuracy: 0.7829
#
# Epoch 00042: val_loss did not improve from 0.65054
# Epoch 43/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6421 - accuracy: 0.7846 - val_loss: 0.6612 - val_accuracy: 0.7776
#
# Epoch 00043: val_loss did not improve from 0.65054
# Epoch 44/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6431 - accuracy: 0.7820 - val_loss: 0.7060 - val_accuracy: 0.7661
#
# Epoch 00044: val_loss did not improve from 0.65054
# Epoch 45/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6357 - accuracy: 0.7835 - val_loss: 0.6606 - val_accuracy: 0.7803
#
# Epoch 00045: val_loss did not improve from 0.65054
# Epoch 46/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6374 - accuracy: 0.7844 - val_loss: 0.6538 - val_accuracy: 0.7790
#
# Epoch 00046: val_loss did not improve from 0.65054
# Epoch 47/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6352 - accuracy: 0.7853 - val_loss: 0.6632 - val_accuracy: 0.7803
#
# Epoch 00047: val_loss did not improve from 0.65054
# Epoch 48/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6317 - accuracy: 0.7866 - val_loss: 0.6567 - val_accuracy: 0.7782
#
# Epoch 00048: val_loss did not improve from 0.65054
# Epoch 49/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6288 - accuracy: 0.7884 - val_loss: 0.6564 - val_accuracy: 0.7898
#
# Epoch 00049: val_loss did not improve from 0.65054
# Epoch 50/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6338 - accuracy: 0.7864 - val_loss: 0.6504 - val_accuracy: 0.7843
#
# Epoch 00050: val_loss improved from 0.65054 to 0.65042, saving model to model/cifar10-cnn-50-0.6504.hdf5
# Epoch 51/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6195 - accuracy: 0.7919 - val_loss: 0.6368 - val_accuracy: 0.7859
#
# Epoch 00051: val_loss improved from 0.65042 to 0.63675, saving model to model/cifar10-cnn-51-0.6368.hdf5
# Epoch 52/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6221 - accuracy: 0.7919 - val_loss: 0.6382 - val_accuracy: 0.7871
#
# Epoch 00052: val_loss did not improve from 0.63675
# Epoch 53/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6117 - accuracy: 0.7954 - val_loss: 0.6634 - val_accuracy: 0.7854
#
# Epoch 00053: val_loss did not improve from 0.63675
# Epoch 54/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6234 - accuracy: 0.7913 - val_loss: 0.6486 - val_accuracy: 0.7843
#
# Epoch 00054: val_loss did not improve from 0.63675
# Epoch 55/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6148 - accuracy: 0.7945 - val_loss: 0.6448 - val_accuracy: 0.7893
#
# Epoch 00055: val_loss did not improve from 0.63675
# Epoch 56/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6234 - accuracy: 0.7925 - val_loss: 0.6503 - val_accuracy: 0.7892
#
# Epoch 00056: val_loss did not improve from 0.63675
# Epoch 57/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6164 - accuracy: 0.7941 - val_loss: 0.6524 - val_accuracy: 0.7861
#
# Epoch 00057: val_loss did not improve from 0.63675
# Epoch 58/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6175 - accuracy: 0.7957 - val_loss: 0.6461 - val_accuracy: 0.7858
#
# Epoch 00058: val_loss did not improve from 0.63675
# Epoch 59/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6063 - accuracy: 0.7944 - val_loss: 0.6529 - val_accuracy: 0.7826
#
# Epoch 00059: val_loss did not improve from 0.63675
# Epoch 60/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6174 - accuracy: 0.7928 - val_loss: 0.6427 - val_accuracy: 0.7863
#
# Epoch 00060: val_loss did not improve from 0.63675
# Epoch 61/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6145 - accuracy: 0.7956 - val_loss: 0.6549 - val_accuracy: 0.7856
#
# Epoch 00061: val_loss did not improve from 0.63675

# %%
from tensorflow.keras.models import load_model
best_model = load_model('./model/cifar10-cnn-51-0.6368.hdf5')

# %%
acc = best_model.evaluate(x_test, y_test, verbose=2)[1]
print(f"\n Test Accuracy: {acc:.4f}")
# Out:
# 313/313 - 1s - loss: 0.6578 - accuracy: 0.7801
#
#  Test Accuracy: 0.7801

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# %%
x_len = np.arange(1, len(y_loss)+1)
plt.figure(figsize=(8,6))
plt.plot(x_len, y_vloss, marker='.', c='red', label='Validationset_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
